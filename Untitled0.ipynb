# %% [markdown]
# <a href="https://colab.research.google.com/github/AdarshBelnekar/AdarshBelnekar/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
import numpy as pd
from tensorflow  import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = pd.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = pd.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 2s 2s/step - loss: 52.9382
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 41.6496
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 32.7683
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 25.7809
# Epoch 5/500
# 1/1 [==============================] - 0s 9ms/step - loss: 20.2836
# Epoch 6/500
# 1/1 [==============================] - 0s 8ms/step - loss: 15.9585
# Epoch 7/500
# 1/1 [==============================] - 0s 8ms/step - loss: 12.5557
# Epoch 8/500
# 1/1 [==============================] - 0s 8ms/step - loss: 9.8786
# Epoch 9/500
# 1/1 [==============================] - 0s 8ms/step - loss: 7.7724
# Epoch 10/500
# 1/1 [==============================] - 0s 8ms/step - loss: 6.1152
# Epoch 11/500
# 1/1 [==============================] - 0s 9ms/step - loss: 4.8115
# Epoch 12/500
# 1/1 [==============================] - 0s 10ms/step - loss: 3.7858
# ...

# %%
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 73ms/step
# [[31.000751]]
